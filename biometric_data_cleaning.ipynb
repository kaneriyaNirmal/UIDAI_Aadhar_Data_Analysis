# %% [markdown]
# **Load Biometric Dataset**

# %%
import pandas as pd

# Load your data
df = pd.read_csv("/content/api_data_aadhar_biometric_full.csv")

df.head(10)
# Out:
#          date              state      district  pincode  bio_age_5_17  \
# 0  01-03-2025            Haryana  Mahendragarh   123029           280
# 1  01-03-2025              Bihar     Madhepura   852121           144
# 2  01-03-2025  Jammu and Kashmir         Punch   185101           643
# 3  01-03-2025              Bihar       Bhojpur   802158           256
# 4  01-03-2025         Tamil Nadu       Madurai   625514           271
# 5  01-03-2025        Maharashtra     Ratnagiri   416702           155
# 6  01-03-2025            Gujarat         Anand   388130            75
# 7  01-03-2025            Gujarat   Gandhinagar   382421           192
# 8  01-03-2025             Odisha     Dhenkanal   759025           122
# 9  01-03-2025            Gujarat        Valsad   396055            67
#
#    bio_age_17_
# 0          577
# 1          369
# 2         1091
# 3          980
# 4          815
# 5          529
# 6          143
# 7          298
# 8          214
# 9           85

# %%
df.shape
# Out:
# (1861108, 6)

# %% [markdown]
# **State Cleaning**

# %%
# Check unique values
df['state'].unique()
# Out:
# array(['Haryana', 'Bihar', 'Jammu and Kashmir', 'Tamil Nadu',
#        'Maharashtra', 'Gujarat', 'Odisha', 'West Bengal', 'Kerala',
#        'Rajasthan', 'Punjab', 'Himachal Pradesh', 'Uttar Pradesh',
#        'Assam', 'Uttarakhand', 'Madhya Pradesh', 'Karnataka',
#        'Andhra Pradesh', 'Telangana', 'Goa', 'Nagaland', 'Jharkhand',
#        'Delhi', 'Chhattisgarh', 'Meghalaya', 'Chandigarh', 'Orissa',
#        'Puducherry', 'Pondicherry', 'Manipur', 'Sikkim', 'Tripura',
#        'Mizoram', 'Arunachal Pradesh', 'Ladakh',
#        'Dadra and Nagar Haveli and Daman and Diu', 'Daman and Diu',
#        'Andaman and Nicobar Islands', 'Andaman & Nicobar Islands',
#        'Dadra and Nagar Haveli', 'Lakshadweep', 'Daman & Diu',
#        'Dadra & Nagar Haveli', 'Jammu & Kashmir', 'WESTBENGAL',
#        'andhra pradesh', 'Westbengal', 'West  Bengal', 'WEST BENGAL',
#        'West Bangal', 'ODISHA', 'odisha', 'West bengal', 'west Bengal',
# ...

# %%
df['state_clean'] = (
    df['state']
    .astype(str)
    .str.strip()                    # remove leading/trailing spaces
    .str.lower()                    # lowercase everything
    .str.replace('&', 'and')        # replace & with and
    .str.replace(r'\s+', ' ', regex=True)  # remove extra spaces
)

# %%
state_corrections = {

    # Andhra Pradesh
    "Andhra Pradesh": "Andhra Pradesh",
    "andhra pradesh": "Andhra Pradesh",

    # Arunachal Pradesh
    "Arunachal Pradesh": "Arunachal Pradesh",

    # Assam
    "Assam": "Assam",

    # Bihar
    "Bihar": "Bihar",

    # Chhattisgarh
    "Chhattisgarh": "Chhattisgarh",
    "Chhatisgarh": "Chhattisgarh",

    # Goa
    "Goa": "Goa",

    # Gujarat
    "Gujarat": "Gujarat",

    # Haryana
    "Haryana": "Haryana",

    # Himachal Pradesh
    "Himachal Pradesh": "Himachal Pradesh",

    # Jharkhand
    "Jharkhand": "Jharkhand",

    # Karnataka
    "Karnataka": "Karnataka",

    # Kerala
    "Kerala": "Kerala",

    # Madhya Pradesh
    "Madhya Pradesh": "Madhya Pradesh",

    # Maharashtra
    "Maharashtra": "Maharashtra",

    # Manipur
    "Manipur": "Manipur",

    # Meghalaya
    "Meghalaya": "Meghalaya",

    # Mizoram
    "Mizoram": "Mizoram",

    # Nagaland
    "Nagaland": "Nagaland",

    # Odisha
    "Odisha": "Odisha",
    "Orissa": "Odisha",
    "ODISHA": "Odisha",
    "odisha": "Odisha",

    # Punjab
    "Punjab": "Punjab",

    # Rajasthan
    "Rajasthan": "Rajasthan",

    # Sikkim
    "Sikkim": "Sikkim",

    # Tamil Nadu
    "Tamil Nadu": "Tamil Nadu",
    "Tamilnadu": "Tamil Nadu",

    # Telangana
    "Telangana": "Telangana",

    # Tripura
    "Tripura": "Tripura",

    # Uttar Pradesh
    "Uttar Pradesh": "Uttar Pradesh",

    # Uttarakhand
    "Uttarakhand": "Uttarakhand",
    "Uttaranchal": "Uttarakhand",

    # West Bengal
    "West Bengal": "West Bengal",
    "WESTBENGAL": "West Bengal",
    "Westbengal": "West Bengal",
    "West  Bengal": "West Bengal",
    "WEST BENGAL": "West Bengal",
    "West Bangal": "West Bengal",
    "West bengal": "West Bengal",
    "west Bengal": "West Bengal",

    # --------------------
    # UNION TERRITORIES
    # --------------------

    # Andaman & Nicobar Islands
    "Andaman and Nicobar Islands": "Andaman and Nicobar Islands",
    "Andaman & Nicobar Islands": "Andaman and Nicobar Islands",

    # Chandigarh
    "Chandigarh": "Chandigarh",

    # Dadra & Nagar Haveli and Daman & Diu
    "Dadra and Nagar Haveli and Daman and Diu": "Dadra and Nagar Haveli and Daman and Diu",
    "Dadra and Nagar Haveli": "Dadra and Nagar Haveli and Daman and Diu",
    "Dadra & Nagar Haveli": "Dadra and Nagar Haveli and Daman and Diu",
    "Daman and Diu": "Dadra and Nagar Haveli and Daman and Diu",
    "Daman & Diu": "Dadra and Nagar Haveli and Daman and Diu",

    # Delhi
    "Delhi": "Delhi",

    # Jammu & Kashmir
    "Jammu and Kashmir": "Jammu and Kashmir",
    "Jammu & Kashmir": "Jammu and Kashmir",

    # Ladakh
    "Ladakh": "Ladakh",

    # Lakshadweep
    "Lakshadweep": "Lakshadweep",

    # Puducherry
    "Puducherry": "Puducherry",
    "Pondicherry": "Puducherry"
}

# %%
df['state_clean'] = df['state'].replace(state_corrections)

# %%
df['state_clean'] = df['state_clean'].str.title()

# %%
df['state_clean'].nunique()
# Out:
# 36

# %% [markdown]
# **Data Understanding**

# %%
df.shape
# Out:
# (1861108, 7)

# %%
df.head()
# Out:
#          date              state      district  pincode  bio_age_5_17  \
# 0  01-03-2025            Haryana  Mahendragarh   123029           280
# 1  01-03-2025              Bihar     Madhepura   852121           144
# 2  01-03-2025  Jammu and Kashmir         Punch   185101           643
# 3  01-03-2025              Bihar       Bhojpur   802158           256
# 4  01-03-2025         Tamil Nadu       Madurai   625514           271
#
#    bio_age_17_        state_clean
# 0          577            Haryana
# 1          369              Bihar
# 2         1091  Jammu And Kashmir
# 3          980              Bihar
# 4          815         Tamil Nadu

# %%
df.isnull().sum()
# Out:
# date            0
# state           0
# district        0
# pincode         0
# bio_age_5_17    0
# bio_age_17_     0
# state_clean     0
# dtype: int64

# %% [markdown]
# **Pincode - Data Cleaning & EDA**

# %%
df['pincode'].head()
# Out:
# 0    123029
# 1    852121
# 2    185101
# 3    802158
# 4    625514
# Name: pincode, dtype: int64

# %%
df['pincode'].dtype
# Out:
# dtype('int64')

# %%
df['pincode'] = df['pincode'].astype(str).str.strip()

# %%
df = df[df['pincode'].str.match(r'^\d+$')]

# %%
df = df[df['pincode'].str.len() == 6]

# %%
# Unique pincodes count
df['pincode'].nunique()
# Out:
# 19707

# %%
# Check min & max (sanity check)
df['pincode'].astype(int).describe()
# Out:
# count    1.861108e+06
# mean     5.217612e+05
# std      1.981627e+05
# min      1.100010e+05
# 25%      3.911750e+05
# 50%      5.224010e+05
# 75%      6.866362e+05
# max      8.554560e+05
# Name: pincode, dtype: float64

# %%
df.shape
# Out:
# (1861108, 7)

# %%
df['pincode'] = df['pincode'].astype(str)

# %% [markdown]
# **Add New Column pincode_first_digit for Deriving Zone Column**

# %%
df['pincode_first_digit'] = df['pincode'].str[0]

# %%
df['pincode_first_digit'].unique()
# Out:
# array(['1', '8', '6', '4', '3', '7', '2', '5'], dtype=object)

# %%
df['pincode'].astype(str).str.len().value_counts()
# Out:
# pincode
# 6    1861108
# Name: count, dtype: int64

# %%
df['pincode'].astype(str).str[0].value_counts().sort_index()
# Out:
# pincode
# 1    136619
# 2    177754
# 3    170580
# 4    258612
# 5    396076
# 6    288343
# 7    313104
# 8    120020
# Name: count, dtype: int64

# %%
df['pincode'].value_counts().head(10)
# Out:
# pincode
# 500055    474
# 500018    436
# 500087    406
# 500090    377
# 450661    359
# 605106    358
# 500067    353
# 509340    353
# 533464    353
# 506006    345
# Name: count, dtype: int64

# %%
df[df['pincode'].astype(str).str.match(r'^0{6}$')]
# Out:
# Empty DataFrame
# Columns: [date, state, district, pincode, bio_age_5_17, bio_age_17_, state_clean, pincode_first_digit]
# Index: []

# %% [markdown]
# **Total Pincode Per State**

# %%
df.groupby('state_clean')['pincode'].nunique().sort_values(ascending=False)
# Out:
# state_clean
# Tamil Nadu                                  2088
# Andhra Pradesh                              1847
# Uttar Pradesh                               1753
# Maharashtra                                 1607
# Kerala                                      1418
# West Bengal                                 1354
# Karnataka                                   1353
# Gujarat                                     1026
# Rajasthan                                    986
# Odisha                                       940
# Bihar                                        917
# Madhya Pradesh                               797
# Telangana                                    653
# Assam                                        574
# Punjab                                       526
# Himachal Pradesh                             448
# Jharkhand                                    364
# Haryana                                      305
# Uttarakhand                                  297
# ...

# %%
df.duplicated(subset=['pincode']).sum()
# Out:
# np.int64(1841401)

# %%
df['pincode'].astype(int).describe()
# Out:
# count    1.861108e+06
# mean     5.217612e+05
# std      1.981627e+05
# min      1.100010e+05
# 25%      3.911750e+05
# 50%      5.224010e+05
# 75%      6.866362e+05
# max      8.554560e+05
# Name: pincode, dtype: float64

# %%
df.shape
# Out:
# (1861108, 8)

# %%
df.head()
# Out:
#          date              state      district pincode  bio_age_5_17  \
# 0  01-03-2025            Haryana  Mahendragarh  123029           280
# 1  01-03-2025              Bihar     Madhepura  852121           144
# 2  01-03-2025  Jammu and Kashmir         Punch  185101           643
# 3  01-03-2025              Bihar       Bhojpur  802158           256
# 4  01-03-2025         Tamil Nadu       Madurai  625514           271
#
#    bio_age_17_        state_clean pincode_first_digit
# 0          577            Haryana                   1
# 1          369              Bihar                   8
# 2         1091  Jammu And Kashmir                   1
# 3          980              Bihar                   8
# 4          815         Tamil Nadu                   6

# %% [markdown]
# **Added Zone Column From Pincode Column**

# %%
df['zone'] = 'Unknown'

df.loc[df['pincode_first_digit'].isin(['1', '2']), 'zone'] = 'North'
df.loc[df['pincode_first_digit'].isin(['3', '4']), 'zone'] = 'West'
df.loc[df['pincode_first_digit'].isin(['5', '6']), 'zone'] = 'South'
df.loc[df['pincode_first_digit'].isin(['7', '8']), 'zone'] = 'East'
df.loc[df['pincode_first_digit'] == '9', 'zone'] = 'Other'

# %%
df[['pincode_first_digit', 'zone']].value_counts().head(10)
# Out:
# pincode_first_digit  zone
# 5                    South    396076
# 7                    East     313104
# 6                    South    288343
# 4                    West     258612
# 2                    North    177754
# 3                    West     170580
# 1                    North    136619
# 8                    East     120020
# Name: count, dtype: int64

# %% [markdown]
# **Zonewise count of Biometric data**

# %%
df['zone'].value_counts()
# Out:
# zone
# South    684419
# East     433124
# West     429192
# North    314373
# Name: count, dtype: int64

# %%
df.shape
# Out:
# (1861108, 9)

# %% [markdown]
# **Applied Data Cleaning & EDA on Date Column**

# %%
df['date'].isnull().sum()
# Out:
# np.int64(0)

# %%
df['date_dt'] = pd.to_datetime(
    df['date'],
    dayfirst=True,
    errors='coerce'
)

# %%
df['date_dt'].isnull().sum()
# Out:
# np.int64(0)

# %%
df.head()
# Out:
#          date              state      district pincode  bio_age_5_17  \
# 0  01-03-2025            Haryana  Mahendragarh  123029           280
# 1  01-03-2025              Bihar     Madhepura  852121           144
# 2  01-03-2025  Jammu and Kashmir         Punch  185101           643
# 3  01-03-2025              Bihar       Bhojpur  802158           256
# 4  01-03-2025         Tamil Nadu       Madurai  625514           271
#
#    bio_age_17_        state_clean pincode_first_digit   zone    date_dt
# 0          577            Haryana                   1  North 2025-03-01
# 1          369              Bihar                   8   East 2025-03-01
# 2         1091  Jammu And Kashmir                   1  North 2025-03-01
# 3          980              Bihar                   8   East 2025-03-01
# 4          815         Tamil Nadu                   6  South 2025-03-01

# %% [markdown]
# **For Further Analysis Derived Year, Month, Month Name, Day Name, Week from Date Column**

# %%
df['year'] = df['date_dt'].dt.year

# %%
df['year'].value_counts().sort_index()
# Out:
# year
# 2025    1861108
# Name: count, dtype: int64

# %%
df['month'] = df['date_dt'].dt.month
df['month_name'] = df['date_dt'].dt.month_name()
df['day_name'] = df['date_dt'].dt.day_name()
df['week'] = df['date_dt'].dt.isocalendar().week

# %%
df.head()
# Out:
#          date              state      district pincode  bio_age_5_17  \
# 0  01-03-2025            Haryana  Mahendragarh  123029           280
# 1  01-03-2025              Bihar     Madhepura  852121           144
# 2  01-03-2025  Jammu and Kashmir         Punch  185101           643
# 3  01-03-2025              Bihar       Bhojpur  802158           256
# 4  01-03-2025         Tamil Nadu       Madurai  625514           271
#
#    bio_age_17_        state_clean pincode_first_digit   zone    date_dt  year  \
# 0          577            Haryana                   1  North 2025-03-01  2025
# 1          369              Bihar                   8   East 2025-03-01  2025
# 2         1091  Jammu And Kashmir                   1  North 2025-03-01  2025
# 3          980              Bihar                   8   East 2025-03-01  2025
# 4          815         Tamil Nadu                   6  South 2025-03-01  2025
#
#    month month_name  day_name  week
# 0      3      March  Saturday     9
# ...

# %% [markdown]
# **Month-wise Count of Biometric Data**

# %%
month_order = [
    'January','February','March','April','May','June',
    'July','August','September','October','November','December'
]

month_counts = (
    df['month_name']
    .value_counts()
    .reindex(month_order, fill_value=0)
)

month_counts
# Out:
# month_name
# January           0
# February          0
# March         21953
# April         21603
# May           21987
# June          21991
# July          22169
# August            0
# September    416846
# October      331715
# November     459086
# December     543758
# Name: count, dtype: int64

# %% [markdown]
# **Day-wise Count of Biometric Data**

# %%
df['day_name'].value_counts().reindex([
    'Monday','Tuesday','Wednesday','Thursday',
    'Friday','Saturday','Sunday'
])
# Out:
# day_name
# Monday       265809
# Tuesday      313583
# Wednesday    232185
# Thursday     276973
# Friday       273221
# Saturday     296437
# Sunday       202900
# Name: count, dtype: int64

# %%
df.groupby(df['date_dt'].dt.to_period('M')).size()
# Out:
# date_dt
# 2025-03     21953
# 2025-04     21603
# 2025-05     21987
# 2025-06     21991
# 2025-07     22169
# 2025-09    416846
# 2025-10    331715
# 2025-11    459086
# 2025-12    543758
# Freq: M, dtype: int64

# %%
df.head()
# Out:
#          date              state      district pincode  bio_age_5_17  \
# 0  01-03-2025            Haryana  Mahendragarh  123029           280
# 1  01-03-2025              Bihar     Madhepura  852121           144
# 2  01-03-2025  Jammu and Kashmir         Punch  185101           643
# 3  01-03-2025              Bihar       Bhojpur  802158           256
# 4  01-03-2025         Tamil Nadu       Madurai  625514           271
#
#    bio_age_17_        state_clean pincode_first_digit   zone    date_dt  year  \
# 0          577            Haryana                   1  North 2025-03-01  2025
# 1          369              Bihar                   8   East 2025-03-01  2025
# 2         1091  Jammu And Kashmir                   1  North 2025-03-01  2025
# 3          980              Bihar                   8   East 2025-03-01  2025
# 4          815         Tamil Nadu                   6  South 2025-03-01  2025
#
#    month month_name  day_name  week
# 0      3      March  Saturday     9
# ...

# %% [markdown]
# **Dropped pincode_first_digit Column**

# %%
df = df.drop(columns=['pincode_first_digit'])

# %%
df.head()
# Out:
#          date              state      district pincode  bio_age_5_17  \
# 0  01-03-2025            Haryana  Mahendragarh  123029           280
# 1  01-03-2025              Bihar     Madhepura  852121           144
# 2  01-03-2025  Jammu and Kashmir         Punch  185101           643
# 3  01-03-2025              Bihar       Bhojpur  802158           256
# 4  01-03-2025         Tamil Nadu       Madurai  625514           271
#
#    bio_age_17_        state_clean   zone    date_dt  year  month month_name  \
# 0          577            Haryana  North 2025-03-01  2025      3      March
# 1          369              Bihar   East 2025-03-01  2025      3      March
# 2         1091  Jammu And Kashmir  North 2025-03-01  2025      3      March
# 3          980              Bihar   East 2025-03-01  2025      3      March
# 4          815         Tamil Nadu  South 2025-03-01  2025      3      March
#
#    day_name  week
# 0  Saturday     9
# 1  Saturday     9
# 2  Saturday     9
# ...

# %% [markdown]
# **Apply Data Cleaning & EDA on District Column**

# %%
df['district'].dtype
# Out:
# dtype('O')

# %%
df['district_clean'] = df['district']

# %%
df.head()
# Out:
#          date              state      district pincode  bio_age_5_17  \
# 0  01-03-2025            Haryana  Mahendragarh  123029           280
# 1  01-03-2025              Bihar     Madhepura  852121           144
# 2  01-03-2025  Jammu and Kashmir         Punch  185101           643
# 3  01-03-2025              Bihar       Bhojpur  802158           256
# 4  01-03-2025         Tamil Nadu       Madurai  625514           271
#
#    bio_age_17_        state_clean   zone    date_dt  year  month month_name  \
# 0          577            Haryana  North 2025-03-01  2025      3      March
# 1          369              Bihar   East 2025-03-01  2025      3      March
# 2         1091  Jammu And Kashmir  North 2025-03-01  2025      3      March
# 3          980              Bihar   East 2025-03-01  2025      3      March
# 4          815         Tamil Nadu  South 2025-03-01  2025      3      March
#
#    day_name  week district_clean
# 0  Saturday     9   Mahendragarh
# ...

# %%
df['district_clean'].isnull().sum()
# Out:
# np.int64(0)

# %%
df['district_clean'].head()
# Out:
# 0    Mahendragarh
# 1       Madhepura
# 2           Punch
# 3         Bhojpur
# 4         Madurai
# Name: district_clean, dtype: object

# %%
df['district'].nunique()
# Out:
# 974

# %%
df['district_clean'].value_counts().head(10)
# Out:
# district_clean
# Pune                 11586
# Thrissur             11165
# East Godavari        10647
# North 24 Parganas    10595
# Barddhaman           10545
# Warangal              9976
# Palakkad              9605
# Karimnagar            9514
# Hyderabad             9422
# Ernakulam             9113
# Name: count, dtype: int64

# %%
df['district_clean'].value_counts().describe()
# Out:
# count      974.000000
# mean      1910.788501
# std       2052.013714
# min          1.000000
# 25%        431.250000
# 50%       1331.000000
# 75%       2489.750000
# max      11586.000000
# Name: count, dtype: float64

# %% [markdown]
# **Dropped State Column And Rename state_clean As State**

# %%
df = df.drop(columns=['state'])
df.rename(columns={'state_clean': 'state'}, inplace=True)

# %%
df['state_correct'] = df['state']

# %%
df.head()
# Out:
#          date      district pincode  bio_age_5_17  bio_age_17_  \
# 0  01-03-2025  Mahendragarh  123029           280          577
# 1  01-03-2025     Madhepura  852121           144          369
# 2  01-03-2025         Punch  185101           643         1091
# 3  01-03-2025       Bhojpur  802158           256          980
# 4  01-03-2025       Madurai  625514           271          815
#
#                state   zone    date_dt  year  month month_name  day_name  \
# 0            Haryana  North 2025-03-01  2025      3      March  Saturday
# 1              Bihar   East 2025-03-01  2025      3      March  Saturday
# 2  Jammu And Kashmir  North 2025-03-01  2025      3      March  Saturday
# 3              Bihar   East 2025-03-01  2025      3      March  Saturday
# 4         Tamil Nadu  South 2025-03-01  2025      3      March  Saturday
#
#    week district_clean      state_correct
# 0     9   Mahendragarh            Haryana
# 1     9      Madhepura              Bihar
# ...

# %% [markdown]
# **Now State-wise cleaning for each district**

# %%
df['state'].unique()
# Out:
# array(['Haryana', 'Bihar', 'Jammu And Kashmir', 'Tamil Nadu',
#        'Maharashtra', 'Gujarat', 'Odisha', 'West Bengal', 'Kerala',
#        'Rajasthan', 'Punjab', 'Himachal Pradesh', 'Uttar Pradesh',
#        'Assam', 'Uttarakhand', 'Madhya Pradesh', 'Karnataka',
#        'Andhra Pradesh', 'Telangana', 'Goa', 'Nagaland', 'Jharkhand',
#        'Delhi', 'Chhattisgarh', 'Meghalaya', 'Chandigarh', 'Puducherry',
#        'Manipur', 'Sikkim', 'Tripura', 'Mizoram', 'Arunachal Pradesh',
#        'Ladakh', 'Dadra And Nagar Haveli And Daman And Diu',
#        'Andaman And Nicobar Islands', 'Lakshadweep'], dtype=object)

# %% [markdown]
# **Example of District Cleaning for West Bengal State**

# %%
df_L = df[df['state'] == 'West Bengal']
df_L.head()
# Out:
#           date           district pincode  bio_age_5_17  bio_age_17_  \
# 11  01-03-2025            Hooghly  712414            91           97
# 12  01-03-2025  Paschim Medinipur  721147            86          116
# 52  01-03-2025    Purba Medinipur  721441            49           53
# 67  01-03-2025            Birbhum  731244            46           52
# 74  01-03-2025  North 24 Parganas  743145           127          234
#
#           state  zone    date_dt  year  month month_name  day_name  week  \
# 11  West Bengal  East 2025-03-01  2025      3      March  Saturday     9
# 12  West Bengal  East 2025-03-01  2025      3      March  Saturday     9
# 52  West Bengal  East 2025-03-01  2025      3      March  Saturday     9
# 67  West Bengal  East 2025-03-01  2025      3      March  Saturday     9
# 74  West Bengal  East 2025-03-01  2025      3      March  Saturday     9
#
#        district_clean state_correct
# 11            Hooghly   West Bengal
# 12  Paschim Medinipur   West Bengal
# ...

# %%
df_L.shape
# Out:
# (2400, 15)

# %%
df_L['district_clean'] = df_L['district']
df_L['district_clean'].unique()
# Out:
# /tmp/ipython-input-1478444784.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_L['district_clean'] = df_L['district']
# array(['Hooghly', 'Paschim Medinipur', 'Purba Medinipur', 'Birbhum',
#        'North 24 Parganas', 'Bankura', 'Barddhaman', 'Maldah',
#        'Jalpaiguri', 'Uttar Dinajpur', 'South 24 Parganas', 'Howrah',
#        'Murshidabad', 'Cooch Behar', 'Nadia', 'Darjeeling', 'Malda',
#        'Kolkata', 'Purulia', 'Paschim Bardhaman', 'Dakshin Dinajpur',
#        'North Twenty Four Parganas', 'Bardhaman', 'Koch Bihar',
#        'Purba Bardhaman', 'South Dinajpur', 'Puruliya', 'Alipurduar',
#        'South Twenty Four Parganas', 'Haora', 'West Midnapore',
#        'Darjiling', 'East Midnapore', 'Jhargram', 'Kalimpong',
# ...

# %%
L_mapping = {
    # Correct districts (already valid)
    'Hooghly': 'Hooghly',
    'Paschim Medinipur': 'Paschim Medinipur',
    'Purba Medinipur': 'Purba Medinipur',
    'Birbhum': 'Birbhum',
    'North Twenty Four Parganas': 'North Twenty Four Parganas',
    'Bankura': 'Bankura',
    'Purba Bardhaman': 'Purba Bardhaman',
    'Malda': 'Malda',
    'Jalpaiguri': 'Jalpaiguri',
    'Uttar Dinajpur': 'Uttar Dinajpur',
    'South Twenty Four Parganas': 'South Twenty Four Parganas',
    'Howrah': 'Howrah',
    'Murshidabad': 'Murshidabad',
    'Cooch Behar': 'Cooch Behar',
    'Nadia': 'Nadia',
    'Darjeeling': 'Darjeeling',
    'Kolkata': 'Kolkata',
    'Purulia': 'Purulia',
    'Paschim Bardhaman': 'Paschim Bardhaman',
    'Dakshin Dinajpur': 'Dakshin Dinajpur',
    'Alipurduar': 'Alipurduar',
    'Jhargram': 'Jhargram',
    'Kalimpong': 'Kalimpong',

    # NOT districts → map to correct district
    'South DumDum(M)': 'North Twenty Four Parganas',
    'Bally Jagachha': 'Howrah',
    'Domjur': 'Howrah'
}

# %%
df_L['district_clean'] = (
    df_L['district_clean']
    .replace(L_mapping)
)
# Out:
# /tmp/ipython-input-1503597074.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_L['district_clean'] = (

# %%
df_L['district_clean'].unique()
# Out:
# array(['Hooghly', 'Paschim Medinipur', 'Purba Medinipur', 'Birbhum',
#        'North Twenty Four Parganas', 'Bankura', 'Purba Bardhaman',
#        'Malda', 'Jalpaiguri', 'Uttar Dinajpur',
#        'South Twenty Four Parganas', 'Howrah', 'Murshidabad',
#        'Cooch Behar', 'Nadia', 'Darjeeling', 'Kolkata', 'Purulia',
#        'Paschim Bardhaman', 'Dakshin Dinajpur', 'Alipurduar', 'Jhargram',
#        'Kalimpong', 'South DumDum(M)', 'Bally Jagachha', 'Domjur'],
#       dtype=object)

# %%
df_L['district_clean'].nunique()
# Out:
# 23

# %%
df.shape
# Out:
# (1861108, 15)

# %% [markdown]
# **Now Added Cleaned District back to Main Table**

# %%
mask = df['state'] == 'West Bengal'
df.loc[mask, 'district'] = df_L['district_clean'].values

# %%
df.shape
# Out:
# (1861107, 15)

# %%
df.head()

# %% [markdown]
# **Validation of District Count**

# %%
df[df['state'] == 'West Bengal']['district'].nunique()
# Out:
# 3

# %% [markdown]
# **Move Districts to Orignal State If State - District Mismatch**

# %%
Tamilnadu_districts_raw = [
      'Viluppuram',
      'Cuddalore'
]

# %%
mask = (
    df['district_clean'].isin(Tamilnadu_districts_raw) &
    (df['state'] == 'Puducherry')
)

df.loc[mask, 'state'] = 'Tamil Nadu'

# %%
df = df[df['district'].str.strip() != '?']

# %%
df.head()
# Out:
#          date      district pincode  bio_age_5_17  bio_age_17_  \
# 0  01-03-2025  Mahendragarh  123029           280          577
# 1  01-03-2025     Madhepura  852121           144          369
# 2  01-03-2025        Poonch  185101           643         1091
# 3  01-03-2025       Bhojpur  802158           256          980
# 4  01-03-2025       Madurai  625514           271          815
#
#                state   zone    date_dt  year  month month_name  day_name  \
# 0            Haryana  North 2025-03-01  2025      3      March  Saturday
# 1              Bihar   East 2025-03-01  2025      3      March  Saturday
# 2  Jammu And Kashmir  North 2025-03-01  2025      3      March  Saturday
# 3              Bihar   East 2025-03-01  2025      3      March  Saturday
# 4         Tamil Nadu  South 2025-03-01  2025      3      March  Saturday
#
#    week district_clean      state_correct
# 0     9   Mahendragarh            Haryana
# 1     9      Madhepura              Bihar
# ...

# %%
#df['state'].nunique()
df['state_correct'].nunique()
# Out:
# 36

# %%
#df['district'].nunique()
df['district_clean'].nunique()
# Out:
# 973

# %% [markdown]
# **Now Dropped state_correct and district_clean**

# %%
df = df.drop(columns=['state_correct', 'district_clean'])

# %%
df.head()
# Out:
#          date      district pincode  bio_age_5_17  bio_age_17_  \
# 0  01-03-2025  Mahendragarh  123029           280          577
# 1  01-03-2025     Madhepura  852121           144          369
# 2  01-03-2025        Poonch  185101           643         1091
# 3  01-03-2025       Bhojpur  802158           256          980
# 4  01-03-2025       Madurai  625514           271          815
#
#                state   zone    date_dt  year  month month_name  day_name  week
# 0            Haryana  North 2025-03-01  2025      3      March  Saturday     9
# 1              Bihar   East 2025-03-01  2025      3      March  Saturday     9
# 2  Jammu And Kashmir  North 2025-03-01  2025      3      March  Saturday     9
# 3              Bihar   East 2025-03-01  2025      3      March  Saturday     9
# 4         Tamil Nadu  South 2025-03-01  2025      3      March  Saturday     9

# %%
df.shape
# Out:
# (1861107, 13)

# %% [markdown]
# **Data Cleaning & EDA on bio_age_5_17**

# %%
df['bio_age_5_17'].dtype
# Out:
# dtype('int64')

# %%
df['bio_age_5_17'].isnull().sum()
# Out:
# np.int64(0)

# %%
(df['bio_age_5_17'] < 0).sum()
# Out:
# np.int64(0)

# %%
df['bio_age_5_17'].describe()
# Out:
# count    1.861107e+06
# mean     1.839059e+01
# std      8.370423e+01
# min      0.000000e+00
# 25%      1.000000e+00
# 50%      3.000000e+00
# 75%      1.100000e+01
# max      8.002000e+03
# Name: bio_age_5_17, dtype: float64

# %%
df.groupby('state')['bio_age_5_17'].sum() \
  .sort_values(ascending=False)
# Out:
# state
# Uttar Pradesh                               6207105
# Maharashtra                                 3512712
# Madhya Pradesh                              3200117
# Tamil Nadu                                  2227256
# Bihar                                       2208141
# Andhra Pradesh                              2138948
# Rajasthan                                   2066747
# Gujarat                                     1460655
# Karnataka                                   1244999
# Odisha                                      1211389
# Telangana                                   1049016
# West Bengal                                 1040512
# Chhattisgarh                                 884555
# Jharkhand                                    876613
# Punjab                                       700162
# Haryana                                      693667
# Kerala                                       647939
# Assam                                        596624
# ...

# %%
df.groupby('district')['bio_age_5_17'].sum() \
  .sort_values(ascending=False).head(15)
# Out:
# district
# Pune               283480
# Kurnool            242992
# Nashik             213100
# East Godavari      204904
# Thane              202896
# Sitapur            200310
# Bengaluru Urban    195876
# Visakhapatnam      195385
# Anantapur          190449
# Prayagraj          188523
# Guntur             187665
# Chittoor           168727
# Ahmedabad          166849
# Bareilly           166397
# Ahilyanagar        165848
# Name: bio_age_5_17, dtype: int64

# %%
(df['bio_age_5_17'] == 0).sum()
# Out:
# np.int64(287669)

# %%
df['bio_age_5_17'].min()
# Out:
# 0

# %%
df['bio_age_5_17'].max()
# Out:
# 8002

# %% [markdown]
# **Data Cleaning & EDA on bio_age_17_**

# %%
df['bio_age_17_'].dtype
# Out:
# dtype('int64')

# %%
df['bio_age_17_'].isnull().sum()
# Out:
# np.int64(0)

# %%
(df['bio_age_17_'] < 0).sum()
# Out:
# np.int64(0)

# %%
df['bio_age_17_'].describe()
# Out:
# count    1.861107e+06
# mean     1.909414e+01
# std      8.806504e+01
# min      0.000000e+00
# 25%      1.000000e+00
# 50%      4.000000e+00
# 75%      1.000000e+01
# max      7.625000e+03
# Name: bio_age_17_, dtype: float64

# %%
df.groupby('district')['bio_age_17_'].sum() \
  .sort_values(ascending=False).head(15)
# Out:
# district
# Thane                        368377
# Nashik                       363506
# Pune                         322282
# Mumbai                       303938
# Bengaluru Urban              300324
# Jalgaon                      268531
# Ahmedabad                    254323
# Nagpur                       238072
# Amravati                     234714
# Yavatmal                     234587
# Nanded                       217810
# Chhatrapati Sambhajinagar    206866
# Ahilyanagar                  203569
# Jaipur                       197591
# North West Delhi             191718
# Name: bio_age_17_, dtype: int64

# %%
df.groupby('state')['bio_age_17_'].sum() \
  .sort_values(ascending=False)
# Out:
# state
# Maharashtra                                 5713427
# Uttar Pradesh                               3370630
# Madhya Pradesh                              2723654
# Bihar                                       2689446
# Tamil Nadu                                  2470876
# Rajasthan                                   1928208
# Chhattisgarh                                1764179
# Gujarat                                     1735859
# West Bengal                                 1484107
# Karnataka                                   1390955
# Odisha                                      1253571
# Andhra Pradesh                              1155803
# Jharkhand                                   1149684
# Telangana                                   1108520
# Punjab                                      1039529
# Kerala                                       961791
# Haryana                                      941787
# Delhi                                        748125
# ...

# %%
df['bio_age_17_'].min()
# Out:
# 0

# %%
df['bio_age_17_'].max()
# Out:
# 7625

# %% [markdown]
# **Now Re-order Columns For Easy Understanding**

# %%
df = df[
    [
        'date',
        'date_dt',
        'year',
        'week',
        'month',
        'month_name',
        'day_name',
        'state',
        'district',
        'pincode',
        'zone',
        'bio_age_5_17',
        'bio_age_17_'
    ]
]

# %%
df.head()
# Out:
#          date    date_dt  year  week  month month_name  day_name  \
# 0  01-03-2025 2025-03-01  2025     9      3      March  Saturday
# 1  01-03-2025 2025-03-01  2025     9      3      March  Saturday
# 2  01-03-2025 2025-03-01  2025     9      3      March  Saturday
# 3  01-03-2025 2025-03-01  2025     9      3      March  Saturday
# 4  01-03-2025 2025-03-01  2025     9      3      March  Saturday
#
#                state      district pincode   zone  bio_age_5_17  bio_age_17_
# 0            Haryana  Mahendragarh  123029  North           280          577
# 1              Bihar     Madhepura  852121   East           144          369
# 2  Jammu And Kashmir        Poonch  185101  North           643         1091
# 3              Bihar       Bhojpur  802158   East           256          980
# 4         Tamil Nadu       Madurai  625514  South           271          815

# %%
df.shape
# Out:
# (1861107, 13)

# %% [markdown]
# **Check for Rows Where bio_age_5_17 and bio_age_17_ is 0 as that and remove that rows as that is not requied for Data Analysis**

# %%
filtered_df = df[
    (df['bio_age_5_17'] == 0) &
    (df['bio_age_17_'] == 0)
]

# %%
len(filtered_df)
# Out:
# 12

# %%
before = len(df)

df = df[~(
    (df['bio_age_5_17'] == 0) &
    (df['bio_age_17_'] == 0)
)]

print("Rows removed:", before - len(df))
# Out:
# Rows removed: 12

# %%
df.shape
# Out:
# (1861095, 13)

# %%
df.head()
# Out:
#          date    date_dt  year  week  month month_name  day_name  \
# 0  01-03-2025 2025-03-01  2025     9      3      March  Saturday
# 1  01-03-2025 2025-03-01  2025     9      3      March  Saturday
# 2  01-03-2025 2025-03-01  2025     9      3      March  Saturday
# 3  01-03-2025 2025-03-01  2025     9      3      March  Saturday
# 4  01-03-2025 2025-03-01  2025     9      3      March  Saturday
#
#                state      district pincode   zone  bio_age_5_17  bio_age_17_
# 0            Haryana  Mahendragarh  123029  North           280          577
# 1              Bihar     Madhepura  852121   East           144          369
# 2  Jammu And Kashmir        Poonch  185101  North           643         1091
# 3              Bihar       Bhojpur  802158   East           256          980
# 4         Tamil Nadu       Madurai  625514  South           271          815

# %% [markdown]
# **Convert bio_age_5_17 to minor_services and bio_age_17_ to Adult_services for Uniform Name across all datasets**

# %%
df['minor_services'] = df['bio_age_5_17']
df['adult_services'] = df['bio_age_17_']

# %% [markdown]
# **Added column Total Activity for Total Updates from minor and Adult Service**

# %%
df['total_activity'] = df['minor_services'] + df['adult_services']

# %% [markdown]
# **Now Added Updated Data back to Biometric Dataset**

# %%
df.to_csv(
    "/content/api_data_aadhar_biometric_v1_cleaned.csv",
    index=False
)
